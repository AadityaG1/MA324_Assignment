# %%
# !pip3 install GEOparse
# Out:
# Requirement already satisfied: GEOparse in c:\users\dell\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy>=1.7 in c:\users\dell\anaconda3\lib\site-packages (from GEOparse) (1.26.4)
# Requirement already satisfied: requests>=2.21.0 in c:\users\dell\anaconda3\lib\site-packages (from GEOparse) (2.27.1)
# Requirement already satisfied: tqdm>=4.31.1 in c:\users\dell\anaconda3\lib\site-packages (from GEOparse) (4.64.0)
# Requirement already satisfied: pandas>=0.17 in c:\users\dell\anaconda3\lib\site-packages (from GEOparse) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.17->GEOparse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas>=0.17->GEOparse) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.17->GEOparse) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.21.0->GEOparse) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.21.0->GEOparse) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.21.0->GEOparse) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\anaconda3\lib\site-packages (from requests>=2.21.0->GEOparse) (2021.10.8)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\lib\site-packages (from tqdm>=4.31.1->GEOparse) (0.4.4)

# %%
import GEOparse

# Download and parse the GEO dataset
gse = GEOparse.get_GEO(geo="GSE7390",destdir="Data")
# Out:
# 05-Apr-2024 17:28:11 DEBUG utils - Directory Data already exists. Skipping.
# 05-Apr-2024 17:28:11 INFO GEOparse - File already exist: using local version.
# 05-Apr-2024 17:28:11 INFO GEOparse - Parsing Data\GSE7390_family.soft.gz:
# 05-Apr-2024 17:28:11 DEBUG GEOparse - DATABASE: GeoMiame
# 05-Apr-2024 17:28:11 DEBUG GEOparse - SERIES: GSE7390
# 05-Apr-2024 17:28:11 DEBUG GEOparse - PLATFORM: GPL96
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177885
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177886
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177887
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177888
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177889
# 05-Apr-2024 17:28:13 DEBUG GEOparse - SAMPLE: GSM177890
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177891
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177892
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177893
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177894
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177895
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177896
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177897
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177898
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177899
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177900
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177901
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177902
# 05-Apr-2024 17:28:14 DEBUG GEOparse - SAMPLE: GSM177903
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177904
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177905
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177906
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177907
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177908
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177909
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177910
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177911
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177912
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177913
# 05-Apr-2024 17:28:15 DEBUG GEOparse - SAMPLE: GSM177914
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177915
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177916
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177917
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177918
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177919
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177920
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177921
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177922
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177923
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177924
# 05-Apr-2024 17:28:16 DEBUG GEOparse - SAMPLE: GSM177925
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177926
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177927
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177928
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177929
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177930
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177931
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177932
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177933
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177934
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177935
# 05-Apr-2024 17:28:17 DEBUG GEOparse - SAMPLE: GSM177936
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177937
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177938
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177939
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177940
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177941
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177942
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177943
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177944
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177945
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177946
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177947
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177948
# 05-Apr-2024 17:28:18 DEBUG GEOparse - SAMPLE: GSM177949
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177950
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177951
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177952
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177953
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177954
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177955
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177956
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177957
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177958
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177959
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177960
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177961
# 05-Apr-2024 17:28:19 DEBUG GEOparse - SAMPLE: GSM177962
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177963
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177964
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177965
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177966
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177967
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177968
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177969
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177970
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177971
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177972
# 05-Apr-2024 17:28:20 DEBUG GEOparse - SAMPLE: GSM177973
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177974
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177975
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177976
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177977
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177978
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177979
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177980
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177981
# 05-Apr-2024 17:28:21 DEBUG GEOparse - SAMPLE: GSM177982
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177983
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177984
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177985
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177986
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177987
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177988
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177989
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177990
# 05-Apr-2024 17:28:22 DEBUG GEOparse - SAMPLE: GSM177991
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177992
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177993
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177994
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177995
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177996
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177997
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177998
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM177999
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM178000
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM178001
# 05-Apr-2024 17:28:23 DEBUG GEOparse - SAMPLE: GSM178002
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178003
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178004
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178005
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178006
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178007
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178008
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178009
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178010
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178011
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178012
# 05-Apr-2024 17:28:24 DEBUG GEOparse - SAMPLE: GSM178013
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178014
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178015
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178016
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178017
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178018
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178019
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178020
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178021
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178022
# 05-Apr-2024 17:28:25 DEBUG GEOparse - SAMPLE: GSM178023
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178024
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178025
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178026
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178027
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178028
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178029
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178030
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178031
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178032
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178033
# 05-Apr-2024 17:28:26 DEBUG GEOparse - SAMPLE: GSM178034
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178035
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178036
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178037
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178038
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178039
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178040
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178041
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178042
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178043
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178044
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178045
# 05-Apr-2024 17:28:27 DEBUG GEOparse - SAMPLE: GSM178046
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178047
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178048
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178049
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178050
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178051
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178052
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178053
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178054
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178055
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178056
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178057
# 05-Apr-2024 17:28:28 DEBUG GEOparse - SAMPLE: GSM178058
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178059
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178060
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178061
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178062
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178063
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178064
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178065
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178066
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178067
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178068
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178069
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178070
# 05-Apr-2024 17:28:29 DEBUG GEOparse - SAMPLE: GSM178071
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178072
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178073
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178074
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178075
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178076
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178077
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178078
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178079
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178080
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178081
# 05-Apr-2024 17:28:30 DEBUG GEOparse - SAMPLE: GSM178082

# %%
import os
import pandas as pd

# Directory where the file will be saved
directory = "Data"

# Check if the directory exists, if not, create it
if not os.path.exists(directory):
    os.makedirs(directory)

# Define a list of example genes relevant to your study
genes = ['BRCA1', 'BRCA2', 'TP53', 'HER2', 'EGFR']

# Convert the list of genes into a pandas DataFrame
gene_df = pd.DataFrame(genes, columns=['Gene'])

# Path to the gene.csv file
file_path = os.path.join(directory, "gene.csv")

# Save the DataFrame to a .csv file
gene_df.to_csv(file_path, index=False)

print(f"'gene.csv' file has been created in the '{directory}' directory.")
# Out:
# 'gene.csv' file has been created in the 'Data' directory.

# %%
import GEOparse
import pandas as pd

# Load the GEO dataset
gse = GEOparse.get_GEO(filepath="Data/GSE7390_family.soft.gz", silent=True)

# Initialize dictionaries to hold sample metadata (gsms), gene expression data (genes), and platform data (gpls)
gsms = {}
genes = {}
gpls = {}

# Extract sample metadata and gene expression data
for gsm_name, gsm in gse.gsms.items():
    gsms[gsm_name] = gsm.metadata['characteristics_ch1']
    genes[gsm_name] = gsm.table

# Extract platform data
for gpl_name, gpl in gse.gpls.items():
    gpls[gpl_name] = gpl.table

# Create a DataFrame from sample metadata and gene expression data
df_list = []
for name in gsms.keys():
    d = dict(zip(genes[name]['ID_REF'], genes[name]['VALUE']))
    d.update(dict(x.split(': ', 1) for x in gsms[name] if ': ' in x))
    df_list.append(d)
df = pd.DataFrame(df_list)

# Save the cleaned data to CSV
df.to_csv("Data/cleaned_data.csv", index=False)

# Display the value counts for 'e.os'
print(df['e.os'].value_counts())

# Read the gene list from the CSV file and filter the dataset based on these genes
gene = pd.read_csv("Data/gene.csv")
relevant_genes = gene["Gene"].values

# Ensure only columns in both 'df' and 'relevant_genes' are selected, plus additional specified metadata columns
columns_to_select = ['sample_name', 'id', 'filename', 'hospital', 'age', 'size', 'Surgery_type', 'Histtype', 'Angioinv', 'Lymp_infil', 'node', 'grade', 'er', 't.rfs', 'e.rfs', 't.os', 'e.os', 't.dmfs', 'e.dmfs', 't.tdm', 'e.tdm', 'risksg', 'NPI', 'risknpi', 'AOL_os_10y', 'risk_AOL', 'veridex_risk']
columns_to_select = [col for col in columns_to_select if col in df.columns] + list(set(relevant_genes) & set(df.columns))

selected = df[columns_to_select]

# Save the filtered data to CSV
selected.to_csv("Data/selected.csv",index=False)
# Out:
# 0    142
# 1     56
# Name: e.os, dtype: int64

# %%
#Data Visualization
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Histogram
data = pd.read_csv("Data/selected.csv")

plt.figure(figsize=(12, 6))
sns.histplot(data['age'], bins=10, kde=True, color='red')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Scatter plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='size', data=data, hue='er')
plt.title('Scatter Plot of Age vs. Tumor Size')
plt.xlabel('Age')
plt.ylabel('Size')
plt.show()

# %%
#Box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x='Surgery_type', y='age', data=data)
plt.title('Box Plot of Age by Surgery Type')
plt.xlabel('Surgery Type')
plt.ylabel('Age')
plt.show()

# %%
#Bar plot
plt.figure(figsize=(12, 6))
sns.countplot(x='Histtype', data=data, palette='viridis')
plt.title('Distribution of Histological Type')
plt.xlabel('Histological Type')
plt.ylabel('Count')
plt.show()

# %%
# !pip install plotnine --user
# Out:
# Collecting plotnine
#   Using cached plotnine-0.13.4-py3-none-any.whl (1.3 MB)
# Collecting statsmodels>=0.14.0
#   Using cached statsmodels-0.14.1-cp39-cp39-win_amd64.whl (10.0 MB)
# Collecting pandas<3.0.0,>=2.1.0
#   Using cached pandas-2.2.1-cp39-cp39-win_amd64.whl (11.6 MB)
# Collecting matplotlib>=3.6.0
#   Using cached matplotlib-3.8.4-cp39-cp39-win_amd64.whl (7.7 MB)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\dell\anaconda3\lib\site-packages (from plotnine) (1.26.4)
# Collecting mizani~=0.11.0
#   Using cached mizani-0.11.1-py3-none-any.whl (127 kB)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\dell\anaconda3\lib\site-packages (from plotnine) (1.13.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (9.0.1)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.2.1-cp39-cp39-win_amd64.whl (182 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib>=3.6.0->plotnine) (3.0.4)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.4.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\dell\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.6.0->plotnine) (3.7.0)
# Requirement already satisfied: tzdata in c:\users\dell\anaconda3\lib\site-packages (from mizani~=0.11.0->plotnine) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\anaconda3\lib\site-packages (from pandas<3.0.0,>=2.1.0->plotnine) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->plotnine) (1.16.0)
# Collecting patsy>=0.5.4
#   Using cached patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Installing collected packages: patsy, pandas, importlib-resources, contourpy, statsmodels, mizani, matplotlib, plotnine
# Successfully installed contourpy-1.2.1 importlib-resources-6.4.0 matplotlib-3.8.4 mizani-0.11.1 pandas-2.2.1 patsy-0.5.6 plotnine-0.13.4 statsmodels-0.14.1

# %%
# pip3 install --upgrade matplotlib

from plotnine import ggplot, aes, geom_bar, geom_boxplot, geom_point, labs, theme, element_text, facet_wrap

# %%
#ggplot version of Scatter plot 

(ggplot(data, aes(x='age', y='size', color='factor(er)'))
 + geom_point()
 + labs(title='Scatter Plot of Age vs. Tumor Size', x='Age', y='Size')
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:141, in ggplot._ipython_display_(self)
#     134 def _ipython_display_(self):
#     135     """
#     136     Display plot in the output of the cell
#     137
#     138     This method will always be called when a ggplot object is the
#     139     last in the cell.
#     140     """
# --> 141     self._display()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     675     sv.figure.savefig(**sv.kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:259, in ggplot.draw(self, show)
#     245 def draw(self, show: bool = False) -> Figure:
#     246     """
#     247     Render the complete plot
#     248
#    (...)
#     257         Matplotlib figure
#     258     """
# --> 259     from ._mpl.layout_engine import PlotnineLayoutEngine
#     261     # Do not draw if drawn already.
#     262     # This prevents a needless error when reusing
#     263     # figure & axes in the jupyter notebook.
#     264     if hasattr(self, "figure"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\_mpl\layout_engine.py:6, in <module>
#       3 import typing
#       4 from dataclasses import asdict, dataclass
# ----> 6 from matplotlib.layout_engine import LayoutEngine
#       7 from matplotlib.text import Text
#       9 if typing.TYPE_CHECKING:
#
# ModuleNotFoundError: No module named 'matplotlib.layout_engine'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:131, in ggplot.__repr__(self)
#     125 msg = (
#     126     "Using repr(plot) to draw and show the plot figure is "
#     127     "deprecated and will be removed in a future version. "
#     128     "Use plot.show()."
#     129 )
#     130 warn(msg, category=FutureWarning, stacklevel=2)
# --> 131 self.show()
#     132 return f"<Figure Size: ({W} x {H})>"
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:150, in ggplot.show(self)
#     143 def show(self):
#     144     """
#     145     Show plot using the matplotlib backend set by the user
#     146
#     147     Users should prefer this method instead of printing or repring
#     148     the object.
#     149     """
# --> 150     self._display() if is_inline_backend() else self.draw(show=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     675     sv.figure.savefig(**sv.kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:259, in ggplot.draw(self, show)
#     245 def draw(self, show: bool = False) -> Figure:
#     246     """
#     247     Render the complete plot
#     248
#    (...)
#     257         Matplotlib figure
#     258     """
# --> 259     from ._mpl.layout_engine import PlotnineLayoutEngine
#     261     # Do not draw if drawn already.
#     262     # This prevents a needless error when reusing
#     263     # figure & axes in the jupyter notebook.
#     264     if hasattr(self, "figure"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\_mpl\layout_engine.py:6, in <module>
#       3 import typing
#       4 from dataclasses import asdict, dataclass
# ----> 6 from matplotlib.layout_engine import LayoutEngine
#       7 from matplotlib.text import Text
#       9 if typing.TYPE_CHECKING:
#
# ModuleNotFoundError: No module named 'matplotlib.layout_engine'

# %%
import matplotlib
pip3 install matplotlib
# Out:
#   Input In [24]
#     pip3 install matplotlib
#          ^
# SyntaxError: invalid syntax

# %%
#Box plot
(ggplot(data, aes(x='Surgery_type', y='age', fill='Surgery_type'))
 + geom_boxplot()
 + labs(title='Box Plot of Age by Surgery Type', x='Surgery Type', y='Age')
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:921, in IPythonDisplayFormatter.__call__(self, obj)
#     919 method = get_real_method(obj, self.print_method)
#     920 if method is not None:
# --> 921     method()
#     922     return True
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:141, in ggplot._ipython_display_(self)
#     134 def _ipython_display_(self):
#     135     """
#     136     Display plot in the output of the cell
#     137
#     138     This method will always be called when a ggplot object is the
#     139     last in the cell.
#     140     """
# --> 141     self._display()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     675     sv.figure.savefig(**sv.kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:259, in ggplot.draw(self, show)
#     245 def draw(self, show: bool = False) -> Figure:
#     246     """
#     247     Render the complete plot
#     248
#    (...)
#     257         Matplotlib figure
#     258     """
# --> 259     from ._mpl.layout_engine import PlotnineLayoutEngine
#     261     # Do not draw if drawn already.
#     262     # This prevents a needless error when reusing
#     263     # figure & axes in the jupyter notebook.
#     264     if hasattr(self, "figure"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\_mpl\layout_engine.py:6, in <module>
#       3 import typing
#       4 from dataclasses import asdict, dataclass
# ----> 6 from matplotlib.layout_engine import LayoutEngine
#       7 from matplotlib.text import Text
#       9 if typing.TYPE_CHECKING:
#
# ModuleNotFoundError: No module named 'matplotlib.layout_engine'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\IPython\core\formatters.py:707, in PlainTextFormatter.__call__(self, obj)
#     700 stream = StringIO()
#     701 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     702     self.max_width, self.newline,
#     703     max_seq_length=self.max_seq_length,
#     704     singleton_pprinters=self.singleton_printers,
#     705     type_pprinters=self.type_printers,
#     706     deferred_pprinters=self.deferred_printers)
# --> 707 printer.pretty(obj)
#     708 printer.flush()
#     709 return stream.getvalue()
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~\anaconda3\lib\site-packages\IPython\lib\pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:131, in ggplot.__repr__(self)
#     125 msg = (
#     126     "Using repr(plot) to draw and show the plot figure is "
#     127     "deprecated and will be removed in a future version. "
#     128     "Use plot.show()."
#     129 )
#     130 warn(msg, category=FutureWarning, stacklevel=2)
# --> 131 self.show()
#     132 return f"<Figure Size: ({W} x {H})>"
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:150, in ggplot.show(self)
#     143 def show(self):
#     144     """
#     145     Show plot using the matplotlib backend set by the user
#     146
#     147     Users should prefer this method instead of printing or repring
#     148     the object.
#     149     """
# --> 150     self._display() if is_inline_backend() else self.draw(show=True)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:175, in ggplot._display(self)
#     172     save_format = "png"
#     174 buf = BytesIO()
# --> 175 self.save(buf, format=save_format, verbose=False)
#     176 display_func = get_display_function(format)
#     177 display_func(buf.getvalue())
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:663, in ggplot.save(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     615 def save(
#     616     self,
#     617     filename: Optional[str | Path | BytesIO] = None,
#    (...)
#     626     **kwargs: Any,
#     627 ):
#     628     """
#     629     Save a ggplot object as an image file
#     630
#    (...)
#     661         Additional arguments to pass to matplotlib `savefig()`.
#     662     """
# --> 663     sv = self.save_helper(
#     664         filename=filename,
#     665         format=format,
#     666         path=path,
#     667         width=width,
#     668         height=height,
#     669         units=units,
#     670         dpi=dpi,
#     671         limitsize=limitsize,
#     672         verbose=verbose,
#     673         **kwargs,
#     674     )
#     675     sv.figure.savefig(**sv.kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:612, in ggplot.save_helper(self, filename, format, path, width, height, units, dpi, limitsize, verbose, **kwargs)
#     609 if dpi is not None:
#     610     self.theme = self.theme + theme(dpi=dpi)
# --> 612 figure = self.draw(show=False)
#     613 return mpl_save_view(figure, fig_kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\ggplot.py:259, in ggplot.draw(self, show)
#     245 def draw(self, show: bool = False) -> Figure:
#     246     """
#     247     Render the complete plot
#     248
#    (...)
#     257         Matplotlib figure
#     258     """
# --> 259     from ._mpl.layout_engine import PlotnineLayoutEngine
#     261     # Do not draw if drawn already.
#     262     # This prevents a needless error when reusing
#     263     # figure & axes in the jupyter notebook.
#     264     if hasattr(self, "figure"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\plotnine\_mpl\layout_engine.py:6, in <module>
#       3 import typing
#       4 from dataclasses import asdict, dataclass
# ----> 6 from matplotlib.layout_engine import LayoutEngine
#       7 from matplotlib.text import Text
#       9 if typing.TYPE_CHECKING:
#
# ModuleNotFoundError: No module named 'matplotlib.layout_engine'
